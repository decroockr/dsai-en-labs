# %%
# Importing the necessary packages
import numpy as np                                  # "Scientific computing"
import scipy.stats as stats                         # Statistical tests

import pandas as pd                                 # Data Frame
from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt                     # Basic visualisation
from statsmodels.graphics.mosaicplot import mosaic  # Mosaic diagram
import seaborn as sns                               # Advanced data visualisation
import altair as alt                                # Alternative visualisation system

# %% [markdown]
# # Hoofdstuk 3A: oefeningen slides

# %%
print(f"P(X > 6) = {stats.norm.sf(6, loc=5, scale=1.5)}")
print(f"P(X > 6) = {stats.norm.sf((6-5)/1.5)}") # met z-score op standaard normaalcurve
print(f"P(X < 4) = {stats.norm.cdf((4-5)/1.5)}")
print(f"P(X < 7) = {stats.norm.cdf((7-5)/1.5)}")
print(f"P(X < 3) = {stats.norm.cdf((3-5)/1.5)}")
print(f"P(2 < X < 6.6) = {stats.norm.cdf((6.5-5)/1.5) - stats.norm.cdf((2-5)/1.5)}")
print(f"x zodat P(X < x) = 0.8 => {stats.norm.isf(1-.8, loc=5, scale=1.5)}")
print(f"x zodat P(X < x) = 0.8 => {stats.norm.isf(0.2) * 1.5 + 5}") # met z-score => isf * standaardafwijking + gemiddelde
# Out:
# P(X > 6) = 0.2524925375469229
# P(X > 6) = 0.2524925375469229
# P(X < 4) = 0.2524925375469229
# P(X < 7) = 0.9087887802741321
# P(X < 3) = 0.09121121972586788
# P(2 < X < 6.6) = 0.8185946141203637
# x zodat P(X < x) = 0.8 => 6.262431850359372
# x zodat P(X < x) = 0.8 => 6.262431850359372

# %% [markdown]
# # Hoofdstuk 3A: oefeningen leerpad

# %%
print(f"oefening1.a : {1 - (5/6)**4}")
print(f"oefening1.b : {1 - (35/36)**24}")

print(f"oefening2: {1- 1/100 * 2/100 * 2/100}")

print("oefening 3:")
df = pd.DataFrame({
    "x": np.arange(start=2, stop=13),
    "noemer": [1, 2, 3, 4, 5, 6, 5, 4, 3, 2, 1]
})
df['fx'] = df.noemer/36
df['xfx'] = df.x * df.fx
df['xfx_inbreng'] = (df.x - 8) * df.fx
print(f"verificatie kansen: {sum(df.fx)}")
print(f"verwachte waarde: {sum(df.xfx)}") # 3.a
print(f"verwachte waarde met inbreng: {sum(df.xfx_inbreng)}") # 3.b
print("E(X-a) = E(X) - a") # 3.c

print("oefening 4:")
df['variantie'] = (df.x - np.average(df.x))**2 * df.fx
print(f"variantie: {sum(df.variantie)}") # 4.a
df['xfx_helft'] = 1/2 * df.x * df.fx
df['xfx_helft_inbreng'] = (1/2 * df.x - 8) * df.fx
print(f"verwachte waarde met inbreng en halve winst: {sum(df.xfx_helft_inbreng)}") # 4.b
print("E(X/a) = E(X)/a") # 4.c
# Out:
# oefening1.a : 0.5177469135802468
# oefening1.b : 0.4914038761309034
# oefening2: 0.999996
# oefening 3:
# verificatie kansen: 1.0000000000000002
# verwachte waarde: 6.999999999999999
# verwachte waarde met inbreng: -0.9999999999999998
# E(X-a) = E(X) - a
# oefening 4:
# variantie: 5.833333333333334
# verwachte waarde met inbreng en halve winst: -4.5
# E(X/a) = E(X)/a

# %% [markdown]
# # Hoofdstuk 3B: slides
